# %%
import glob                  # Librairie pour parcourir les dossier et fichier sur le disk
import os
from lxml import etree as ET # pour parcourir les fichiers XML de grande taille
import zipfile
import csv
import logging
import shutil

# %%
# Création du CSV qui contient les données des points de ventes
pdvcsvfile = open('pdv.csv', 'w')
pdvnames   = ["annee",
              "id",
              "latitude",
              "longitude",
              "cp",
              "pop",
              "ouverture_debut",
              "ouverture_fin",
              "ouverture_saufjour",
              "adresse",
              "ville"]
pdv_writer = csv.DictWriter(pdvcsvfile, fieldnames=pdvnames)
pdv_writer.writeheader()

# Création du CSV qui contient les données des ruptures
rupturescsvfile = open('ruptures.csv', 'w')
rupturesnames = ["annee",
                 "id_pdv",
                 "id",
                 "nom",
                 "debut",
                 "fin"]
ruptures_writer = csv.DictWriter(rupturescsvfile, fieldnames=rupturesnames)
ruptures_writer.writeheader()

# Création du CSV qui contient les données des fermetures
fermeturescsvfile = open('fermetures.csv', 'w')
fermeturesnames = ["annee",
                   "id_pdv",
                   "type",
                   "debut",
                   "fin"]
fermetures_writer = csv.DictWriter(fermeturescsvfile, fieldnames=fermeturesnames)
fermetures_writer.writeheader()


# Création du CSV qui contient les données des prix
prixcsvfile = open('prix.csv', 'w')
prixnames   = ["annee",
              "id_pdv",
              "nom",
              "id",
              "maj",
              "valeur"]
prix_writer = csv.DictWriter(prixcsvfile, fieldnames=prixnames)
prix_writer.writeheader()

# Création du CSV qui contient les données des services
servicescsvfile = open('services.csv', 'w')
servicesnames   = ["annee",
                   "id_pdv",
                   "service"]
services_writer = csv.DictWriter(servicescsvfile, fieldnames=servicesnames)
services_writer.writeheader()


# Initialisation des dictionnaire des lignes temporiaires à inserer dans les csv
pdv_row        = dict.fromkeys(pdvnames)
ruptures_row   = dict.fromkeys(rupturesnames)
fermetures_row = dict.fromkeys(fermeturesnames)
prix_row       = dict.fromkeys(prixnames)
services_row   = dict.fromkeys(servicesnames)

# %%
# txt_path : fonction qui prend une balise du XML (element), 
	# le chemin de la valeur qu’on souhaite récupérer (path) 
def txt_path(element, path):
    if element.find(path) is not None:
        res = str(element.find(path).text)
        return res
    return ""

# %%
pdvcsvfile.close()
rupturescsvfile.close()
fermeturescsvfile.close()
servicescsvfile.close()
prixcsvfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bcef71727477> in <module>
# ----> 1 pdvcsvfile.close()
#       2 rupturescsvfile.close()
#       3 fermeturescsvfile.close()
#       4 servicescsvfile.close()
#       5 prixcsvfile.close()
#
# NameError: name 'pdvcsvfile' is not defined

# %%
def process_prix(annee, id_pdv, prix):
    pass

# %%
def process_service(annee, id_pdv, service):
    pass

# %%
def process_rupture(annee, id_pdv, rupture):
    pass

# %%
def process_fermeture(annee, id_pdv, fermeture):
    pass

# %%
def process_pdv(annee, pdv):
    pdv_row['annee']= annee
    for name, value in sorted(pdv.items()):
        pdv_row[name] = value
        
    id_pdv = pdv_row['id']
    for prix in pdv.findall('prix'):
        process_prix(annee, id_pdv, prix)
    
    for service in pdv.findall('services/service'):
        process_service(annee, id_pdv, service)
    
    for rupture in pdv.findall('rupture'):
        process_rupture(annee, id_pdv, rupture)
        
    for fermeture in pdv.findall('fermeture'):
        process_fermeture(annee, id_pdv, fermeture)

# %%
import re

# %%
i = "aa/data/PrixCarburants_annuel_2019.zip"
r = re.findall('([^/]*\d{4})\.zip',i)[0] + ".xml"
print(r)
# Out:
# PrixCarburants_annuel_2019.xml

# %%
for pathZip in glob.glob('data/PrixC*2007.zip'):
        annee   = re.findall('.*(\d{4})\.zip',i)[0]
        xml     = re.findall('([^/]*\d{4})\.zip',i)[0] + ".xml"

        # lire le zip
        logging.debug("Opening ZIP file " + pathZip)    
        zf = zipfile.ZipFile(pathZip, 'r')
        # lire le XML
        f  = zf.open(nameXml)
        # créer le XMLReader
        context = ET.iterparse(f, events=('end',), tag='pdv')
        for event, pdv in context:
            print(pdv.find('ouverture').items())
        # fermer le zip
        zf.close()
# Out:
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:45'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '16:00'), ('fin', '20:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '17:30'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', 'Lundi;Mardi;Mercredi;Jeudi;Vendredi;Samedi')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:45'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:45'), ('fin', '19:15'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '19:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:30'), ('fin', '19:45'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:45'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Lundi;Mardi;Mercredi;Jeudi;Vendredi;Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '18:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:15'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:15'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:15'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Lundi')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:45'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '18:30'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:45'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:15'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '23:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '18:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '18:30'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Lundi')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', 'Lundi')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Jeudi')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '08:45'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Lundi')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:30'), ('saufjour', 'Mercredi')]
# [('debut', '08:00'), ('fin', '18:30'), ('saufjour', 'Lundi')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:45'), ('fin', '19:45'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:45'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', 'Lundi')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:45'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:45'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:45'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:30'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:15'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:15'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '21:30'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '18:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '07:30'), ('fin', '18:30'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '18:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Mercredi')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '19:15'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Lundi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:30'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:30'), ('saufjour', 'Lundi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '19:45'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '23:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:45'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# ...
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:30'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:30'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:30'), ('saufjour', 'Lundi;Mardi;Mercredi;Jeudi;Vendredi;Samedi')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '08:30'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '18:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '19:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '07:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '07:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:30'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:30'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '08:00'), ('fin', '20:15'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '03:00'), ('fin', '18:30'), ('saufjour', 'Dimanche')]
# [('debut', '02:00'), ('fin', '17:00'), ('saufjour', 'Dimanche')]
# [('debut', '05:00'), ('fin', '23:00'), ('saufjour', 'Lundi;Mardi;Mercredi;Jeudi;Vendredi;Samedi')]
# [('debut', '05:00'), ('fin', '23:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', 'Dimanche')]
# [('debut', '00:00'), ('fin', '19:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:30'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Samedi;Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '19:30'), ('saufjour', 'Dimanche')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '08:15'), ('fin', '19:15'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '20:00'), ('saufjour', '')]
# [('debut', '09:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '07:15'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', 'Dimanche')]
# [('debut', '00:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '20:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '08:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '09:00'), ('fin', '20:00'), ('saufjour', 'Dimanche')]
# [('debut', '06:45'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:59'), ('saufjour', '')]
# [('debut', '00:00'), ('fin', '23:45'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '19:00'), ('saufjour', 'Dimanche')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '22:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '05:30'), ('fin', '22:30'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '00:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '01:00'), ('fin', '01:00'), ('saufjour', '')]
# [('debut', '06:00'), ('fin', '21:00'), ('saufjour', '')]
